# %% [markdown]
# # Etapa 3: Análisis de datos utilizando SQL

# %% [markdown]
# ## Objetivos
#
# En esta práctica subiremos los datos a una base de datos SQL y realizaremos diferentes queries para obtener información sobre los datos

# %%
# !pip install sqlalchemy==1.4.16 --quiet
import pandas as pd
import numpy as np
# !pip install PyMySQL --quiet
import pymysql as pymsql
# !pip install mysql-connector --quiet
import mysql.connector
from sqlalchemy import create_engine
# !pip install sqlalchemy-utils --quiet
from sqlalchemy_utils import database_exists, create_database
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Tarea 1: Subir los datos a la base de datos:

# %% [markdown]
# Primero cargamos el archivo de datos `dataset_part_2.csv`.

# %%
df_path = "dataset_part_2.csv"
df = pd.read_csv(df_path)

# %%
#Rellena la siguiente variable con tu nombre y apellido (Todo junto y sin espacios).
nombreBD = 'paulagarcia'
linkConexion = 'mysql+mysqlconnector://alumno:385bd4cf713a8a36@35.180.211.139/' + nombreBD
#Establecemos la conexión
engine = create_engine(linkConexion)

# %%
if not database_exists(engine.url):
    create_database(engine.url)

# %%
# Añadir el dataframe a sql SPACEXTBL usando la función to_sql().
df.to_sql('SPACEXTBL', con=engine, if_exists='append', index=False)
# Out:
# -1

# %%
query = "select * from SPACEXTBL;"
df  = pd.read_sql(query,  engine )
df
# Out:
#     FlightNumber        Date BoosterVersion   PayloadMass  \
# 0            1.0  2010-06-04       Falcon 9   6123.547647
# 1            2.0  2012-05-22       Falcon 9    525.000000
# 2            3.0  2013-03-01       Falcon 9    677.000000
# 3            4.0  2013-09-29       Falcon 9    500.000000
# 4            5.0  2013-12-03       Falcon 9   3170.000000
# ..           ...         ...            ...           ...
# 88          89.0  2020-10-24       Falcon 9  15600.000000
# 89          90.0  2020-11-05       Falcon 9   3681.000000
# 90           NaN        None           None           NaN
# 91           NaN        None           None           NaN
# 92           NaN        None           None           NaN
#
#                       Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0   Dragon Qualification Unit   LEO  CCSFS SLC 40      None None      1.0
# 1          COTS Demo Flight 2   LEO  CCSFS SLC 40      None None      1.0
# 2                       CRS-2   ISS  CCSFS SLC 40      None None      1.0
# 3                    CASSIOPE    PO   VAFB SLC 4E    False Ocean      1.0
# 4                       SES-8   GTO  CCSFS SLC 40      None None      1.0
# ..                        ...   ...           ...            ...      ...
# 88                Starlink-14  VLEO  CCSFS SLC 40      True ASDS      3.0
# 89   GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS      1.0
# 90                       None  None  CCSFS SLC 40           None      NaN
# 91                       None  None   VAFB SLC 4E           None      NaN
# 92                       None  None    KSC LC 39A           None      NaN
#
#     GridFins  Reused  Legs                LandingPad  Block  \
# 0        0.0     0.0   0.0                      None    1.0
# 1        0.0     0.0   0.0                      None    1.0
# 2        0.0     0.0   0.0                      None    1.0
# 3        0.0     0.0   0.0                      None    1.0
# 4        0.0     0.0   0.0                      None    1.0
# ..       ...     ...   ...                       ...    ...
# 88       1.0     1.0   1.0  5e9e3033383ecbb9e534e7cc    5.0
# 89       1.0     0.0   1.0  5e9e3032383ecb6bb234e7ca    5.0
# 90       NaN     NaN   NaN                      None    NaN
# 91       NaN     NaN   NaN                      None    NaN
# 92       NaN     NaN   NaN                      None    NaN
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                      SpaceX              1.0          0.0  B0003
# 1                  NASA(COTS)              1.0          0.0  B0005
# 2                  NASA (CRS)              1.0          0.0  B0007
# 3                         MDA              1.0          0.0  B1003
# 4                         SES              1.0          0.0  B1004
# ..                        ...              ...          ...    ...
# 88                     SpaceX              1.0         12.0  B1060
# 89  United States Space Force              1.0          8.0  B1062
# 90                       None              NaN          NaN   None
# 91                       None              NaN          NaN   None
# 92                       None              NaN          NaN   None
#
#      Longitude   Latitude  Class
# 0   -80.577366  28.561857    0.0
# 1   -80.577366  28.561857    0.0
# 2   -80.577366  28.561857    0.0
# 3  -120.610829  34.632093    0.0
# 4   -80.577366  28.561857    0.0
# ..         ...        ...    ...
# 88  -80.577366  28.561857    1.0
# 89  -80.577366  28.561857    1.0
# 90         NaN        NaN    NaN
# 91         NaN        NaN    NaN
# 92         NaN        NaN    NaN
#
# [93 rows x 21 columns]

# %% [markdown]
# ## Tarea 2: Queries con SQL

# %% [markdown]
# ### Ejercicio 1
#
# ##### Muestra las diferentes plataformas de lanzamiento:

# %%
#Rellena la variable query con tu consulta
query = """ SELECT DISTINCT LaunchSite
            FROM  SPACEXTBL;"""
df  = pd.read_sql(query, con = engine )
df
# Out:
#      LaunchSite
# 0  CCSFS SLC 40
# 1   VAFB SLC 4E
# 2    KSC LC 39A

# %% [markdown]
# ### Ejercicio 2
#
# ##### Muestra 5 lanzamientos cuya plataforma empiece por 'CCS'

# %%
#Rellena la variable query con tu consulta
query = """ SELECT LaunchSite, BoosterVersion
            FROM  SPACEXTBL
            WHERE LaunchSite LIKE 'CCS%'
            LIMIT 5"""
df  = pd.read_sql(query, con = engine )
df
# Out:
#      LaunchSite BoosterVersion
# 0  CCSFS SLC 40       Falcon 9
# 1  CCSFS SLC 40       Falcon 9
# 2  CCSFS SLC 40       Falcon 9
# 3  CCSFS SLC 40       Falcon 9
# 4  CCSFS SLC 40       Falcon 9

# %% [markdown]
# ### Ejercicio 3
#
# ##### Mustra el la masa total transportada por los lanzamientos realizados donde el cliente es NASA (CRS)

# %%
query = """ SELECT LaunchSite, BoosterVersion
            FROM  SPACEXTBL
            WHERE LaunchSite LIKE 'CCS%'
            LIMIT 5"""
df  = pd.read_sql(query, con = engine )
df

# %% [markdown]
# ### Ejercicio 4
#
# ##### Muestra la masa media tranportada por lanzamientos con serie que comienza por B1

# %%
query = """   """
df  = pd.read_sql(query, con = engine )
df

# %% [markdown]
# ### Ejercicio 5
#
# ##### Muestra la fecha donde se realizo el primer aterrizaje exitoso sobre terreno (TRUE RTLS)
#
# *Pista:Utiliza la función min*

# %%
query = """   """
df  = pd.read_sql(query, con = engine )
df

# %% [markdown]
# ### Ejercicio 6
#
# ##### Muestra las series de los cohetes que aterrizaron sobre portaviones (TRUE ASDS) con una masa entre 4000 y 6000

# %% [markdown]
# ### Ejercicio 7
#
# ##### Muestra el numero de lanzamientos que completaron su mision correctamente y aquellos que fallaron

# %% [markdown]
# ### Ejercicio 8
#
# ##### Muestra las series de los cohetes que transportaron la masa máxima

# %% [markdown]
# ### Ejercicio 9
#
# ##### Muestra los el resultados del aterrizaje, la serie del cohete y las plataforma de lanzamiento de aquellos lanzamientos fallidos o no intentados en el año 2015

# %% [markdown]
# ### Ejercicio 10
#
# ##### Muestra los resultados y la frecuencia de estos resultados entre 2010-06-04 y 2017-03-20 ordenados en orden descendiente según la frecuencia
